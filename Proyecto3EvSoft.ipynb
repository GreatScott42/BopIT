# %% [markdown]
# <a href="https://colab.research.google.com/github/GreatScott42/BopIT/blob/master/Proyecto3EvSoft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
from google.colab import files

#data = pd.read_excel("https://raw.githubusercontent.com/ClaudixoPG/ESI_2025_S1/main/datasets/guess_proyecto3_datos.xlsx")
#data2 = pd.read_excel("https://raw.githubusercontent.com/ClaudixoPG/ESI_2025_S1/main/datasets/Minecraft_Evaluacion_GUESS.xlsx")

datav1 = pd.read_excel("https://github.com/GreatScott42/guessDatasetEvSoft/raw/refs/heads/main/guessv1.xlsx")
datav2 = pd.read_excel("https://github.com/GreatScott42/guessDatasetEvSoft/raw/refs/heads/main/guessv2.xlsx")

#datav1.head()
datav2.head()
# Out:
#   user_id version  AE1  AE2  AE3  AE4  PE1  PE2  PE3  PE4  ...  US2  US3  US4  \
# 0  user_1      v2    6    5    5    3    5    5    5    5  ...    4    6    5
# 1  user_2      v2    6    7    5    4    6    5    4    5  ...    4    3    4
# 2  user_3      v2    7    5    5    4    6    5    5    5  ...    7    5    4
# 3  user_4      v2    6    4    6    6    6    6    4    5  ...    7    6    5
# 4  user_5      v2    5    5    3    6    4    4    6    4  ...    4    3    5
#
#    US5  US6  US7  VA1  VA2  VA3  VA4
# 0    6    4    6    4    5    6    5
# 1    4    5    5    4    5    3    5
# 2    5    5    3    3    5    6    5
# 3    3    5    4    6    4    5    5
# 4    6    5    4    4    4    6    5
#
# [5 rows x 47 columns]

# %%
#valores y promedios
aest1 = datav1[['AE1','AE2','AE3','AE4']].mean(axis=1)
playEngross1 = datav1[['PE1','PE2','PE3','PE4','PE5','PE6','PE7']].mean(axis=1)
enjoy1 = datav1[['EN1','EN2','EN3','EN4','EN5','EN6']].mean(axis=1)
personalGrat1 = datav1[['PG1','PG2','PG3','PG4']].mean(axis=1)
creativeFree1 = datav1[['CF1','CF2','CF3','CF4']].mean(axis=1)
socialConnect1 = datav1[['SC1','SC2','SC3','SC4','SC5']].mean(axis=1)
narrative1 = datav1[['NA1','NA2','NA3','NA4']].mean(axis=1)
usability1 = datav1[['US1','US2','US3','US4','US5','US6','US7']].mean(axis=1)
visualAest1 = datav1[['VA1','VA2','VA3','VA4']].mean(axis=1)

mean_aest1 = aest1.mean(axis=0)
mean_playEngross1 = playEngross1.mean(axis=0)
mean_enjoy1 = enjoy1.mean(axis=0)
mean_personalGrat1 = personalGrat1.mean(axis=0)
mean_creativeFree1 = creativeFree1.mean(axis=0)
mean_socialConnect1 = socialConnect1.mean(axis=0)
mean_narrative1 = narrative1.mean(axis=0)
mean_usability1 = usability1.mean(axis=0)
mean_visualAest1 = visualAest1.mean(axis=0)

mean_data1 = {
    'Subescala': ['Aesthetics', 'Play Engrossment', 'Enjoyment',
                  'Personal Gratification', 'Creative Freedom',
                  'Social Connectivity', 'Narrative',
                  'Usability/Playability', 'Visual Aesthetics'],
    'Media V1': [mean_aest1, mean_playEngross1, mean_enjoy1,
                 mean_personalGrat1, mean_creativeFree1,
                 mean_socialConnect1, mean_narrative1,
                 mean_usability1, mean_visualAest1]
}


resultados_v1 = pd.DataFrame(mean_data1)
resultados_v1
# Out:
#                 Subescala  Media V1
# 0              Aesthetics  4.525000
# 1        Play Engrossment  4.528571
# 2               Enjoyment  4.380000
# 3  Personal Gratification  4.460000
# 4        Creative Freedom  5.030000
# 5     Social Connectivity  4.472000
# 6               Narrative  4.425000
# 7   Usability/Playability  4.454286
# 8       Visual Aesthetics  4.405000

# %%
aest2 = datav2[['AE1','AE2','AE3','AE4']].mean()
playEngross2 = datav2[['PE1','PE2','PE3','PE4','PE5','PE6','PE7']].mean()
enjoy2 = datav2[['EN1','EN2','EN3','EN4','EN5','EN6']].mean()
personalGrat2 = datav2[['PG1','PG2','PG3','PG4']].mean()
creativeFree2 = datav2[['CF1','CF2','CF3','CF4']].mean()
socialConnect2 = datav2[['SC1','SC2','SC3','SC4','SC5']].mean()
narrative2 = datav2[['NA1','NA2','NA3','NA4']].mean()
usability2 = datav2[['US1','US2','US3','US4','US5','US6','US7']].mean()
visualAest2 = datav2[['VA1','VA2','VA3','VA4']].mean()

mean_aest2 = aest2.mean(axis=0)
mean_playEngross2 = playEngross2.mean(axis=0)
mean_enjoy2 = enjoy2.mean(axis=0)
mean_personalGrat2 = personalGrat2.mean(axis=0)
mean_creativeFree2 = creativeFree2.mean(axis=0)
mean_socialConnect2 = socialConnect2.mean(axis=0)
mean_narrative2 = narrative2.mean(axis=0)
mean_usability2 = usability2.mean(axis=0)
mean_visualAest2 = visualAest2.mean(axis=0)

mean_data2 = {
    'Subescala': ['Aesthetics', 'Play Engrossment', 'Enjoyment',
                  'Personal Gratification', 'Creative Freedom',
                  'Social Connectivity', 'Narrative',
                  'Usability/Playability', 'Visual Aesthetics'],
    'Media V2': [mean_aest2, mean_playEngross2, mean_enjoy2,
                 mean_personalGrat2, mean_creativeFree2,
                 mean_socialConnect2, mean_narrative2,
                 mean_usability2, mean_visualAest2]
}


resultados_v2 = pd.DataFrame(mean_data2)
resultados_v2
# Out:
#                 Subescala  Media V2
# 0              Aesthetics  4.895000
# 1        Play Engrossment  4.920000
# 2               Enjoyment  4.823333
# 3  Personal Gratification  4.810000
# 4        Creative Freedom  5.020000
# 5     Social Connectivity  4.864000
# 6               Narrative  4.840000
# 7   Usability/Playability  4.842857
# 8       Visual Aesthetics  4.815000

# %%
#valores estandar
std_aest1 = aest1.std(axis=0)
std_playEngross1 = playEngross1.std(axis=0)
std_enjoy1 = enjoy1.std(axis=0)
std_personalGrat1 = personalGrat1.std(axis=0)
std_creativeFree1 = creativeFree1.std(axis=0)
std_socialConnect1 = socialConnect1.std(axis=0)
std_narrative1 = narrative1.std(axis=0)
std_usability1 = usability1.std(axis=0)
std_visualAest1 = visualAest1.std(axis=0)

desviacionE_data1 = {
    'Subescala': ['Aesthetics', 'Play Engrossment', 'Enjoyment',
                  'Personal Gratification', 'Creative Freedom',
                  'Social Connectivity', 'Narrative',
                  'Usability/Playability', 'Visual Aesthetics'],
    'desviacionE V1': [std_aest1, std_playEngross1, std_enjoy1,
              std_personalGrat1, std_creativeFree1,
              std_socialConnect1, std_narrative1,
              std_usability1, std_visualAest1]
}
desviacionE1 = pd.DataFrame(desviacionE_data1)
desviacionE1
# Out:
#                 Subescala  desviacionE V1
# 0              Aesthetics        0.446786
# 1        Play Engrossment        0.384248
# 2               Enjoyment        0.346737
# 3  Personal Gratification        0.452769
# 4        Creative Freedom        0.301527
# 5     Social Connectivity        0.399510
# 6               Narrative        0.537497
# 7   Usability/Playability        0.347167
# 8       Visual Aesthetics        0.425255

# %%
std_aest2 = aest2.std(axis=0)
std_playEngross2 = playEngross2.std(axis=0)
std_enjoy2 = enjoy2.std(axis=0)
std_personalGrat2 = personalGrat2.std(axis=0)
std_creativeFree2 = creativeFree2.std(axis=0)
std_socialConnect2 = socialConnect2.std(axis=0)
std_narrative2 = narrative2.std(axis=0)
std_usability2 = usability2.std(axis=0)
std_visualAest2 = visualAest2.std(axis=0)

desviacionE_data2 = {
    'Subescala': ['Aesthetics', 'Play Engrossment', 'Enjoyment',
                  'Personal Gratification', 'Creative Freedom',
                  'Social Connectivity', 'Narrative',
                  'Usability/Playability', 'Visual Aesthetics'],
    'desviacionE V1': [std_aest1, std_playEngross1, std_enjoy1,
              std_personalGrat1, std_creativeFree1,
              std_socialConnect1, std_narrative1,
              std_usability1, std_visualAest1],
    'desviacionE V2': [std_aest2, std_playEngross2, std_enjoy2,
                       std_personalGrat2, std_creativeFree2,
                       std_socialConnect2, std_narrative2,
                       std_usability2, std_visualAest2]
}

desviacionE2 = pd.DataFrame(desviacionE_data2)
desviacionE2
# Out:
#                 Subescala  desviacionE V1  desviacionE V2
# 0              Aesthetics        0.446786        0.180647
# 1        Play Engrossment        0.384248        0.130128
# 2               Enjoyment        0.346737        0.140523
# 3  Personal Gratification        0.452769        0.110151
# 4        Creative Freedom        0.301527        0.117757
# 5     Social Connectivity        0.399510        0.153232
# 6               Narrative        0.537497        0.191833
# 7   Usability/Playability        0.347167        0.120791
# 8       Visual Aesthetics        0.425255        0.126886

# %%
promedios = pd.DataFrame({
    'Subescala': ['Aesthetics', 'Play Engrossment', 'Enjoyment',
                  'Personal Gratification', 'Creative Freedom',
                  'Social Connectivity', 'Narrative',
                  'Usability/Playability', 'Visual Aesthetics'],
    'Media V1': [mean_aest1, mean_playEngross1, mean_enjoy1,
                 mean_personalGrat1, mean_creativeFree1,
                 mean_socialConnect1, mean_narrative1,
                 mean_usability1, mean_visualAest1],
    'Media V2': [mean_aest2, mean_playEngross2, mean_enjoy2,
                 mean_personalGrat2, mean_creativeFree2,
                 mean_socialConnect2, mean_narrative2,
                 mean_usability2, mean_visualAest2]
})



promedio = pd.melt(promedios,id_vars='Subescala',value_vars=['Media V1', 'Media V2'],var_name='Version', value_name='Media')
plt.figure(figsize=(12,6))
sns.barplot(data=promedio, x='Subescala', y='Media', hue='Version')

plt.xticks(rotation=45)
plt.title('Comparación de medias por subescala version 1 vs version 2)')
plt.ylabel('Media')
plt.xlabel('Subescala')
plt.tight_layout()
plt.show()

# %%
promediosT = promedios.T
promedios
# Out:
#                 Subescala  Media V1  Media V2
# 0              Aesthetics  4.525000  4.895000
# 1        Play Engrossment  4.528571  4.920000
# 2               Enjoyment  4.380000  4.823333
# 3  Personal Gratification  4.460000  4.810000
# 4        Creative Freedom  5.030000  5.020000
# 5     Social Connectivity  4.472000  4.864000
# 6               Narrative  4.425000  4.840000
# 7   Usability/Playability  4.454286  4.842857
# 8       Visual Aesthetics  4.405000  4.815000

# %%
#t test
from scipy import stats
#

aesthetics_cols = ['AE1','AE2','AE3','AE4']
play_engrossment_cols = ['PE1','PE2','PE3','PE4','PE5','PE6','PE7']
enjoyment_cols = ['EN1','EN2','EN3','EN4','EN5','EN6']
personal_gratification_cols = ['PG1','PG2','PG3','PG4']
creative_freedom_cols = ['CF1','CF2','CF3','CF4']
social_connectivity_cols = ['SC1','SC2','SC3','SC4','SC5']
narrative_cols = ['NA1','NA2','NA3','NA4']
usability_cols = ['US1','US2','US3','US4','US5','US6','US7']
visual_aesthetics_cols = ['VA1','VA2','VA3','VA4']

datav1['Aesthetics'] = datav1[aesthetics_cols].mean(axis=1)
datav1['Play Engrossment'] = datav1[play_engrossment_cols].mean(axis=1)
datav1['Enjoyment'] = datav1[enjoyment_cols].mean(axis=1)
datav1['Personal Gratification'] = datav1[personal_gratification_cols].mean(axis=1)
datav1['Creative Freedom'] = datav1[creative_freedom_cols].mean(axis=1)
datav1['Social Connectivity'] = datav1[social_connectivity_cols].mean(axis=1)
datav1['Narrative'] = datav1[narrative_cols].mean(axis=1)
datav1['Usability/Playability'] = datav1[usability_cols].mean(axis=1)
datav1['Visual Aesthetics'] = datav1[visual_aesthetics_cols].mean(axis=1)

datav2['Aesthetics'] = datav2[aesthetics_cols].mean(axis=1)
datav2['Play Engrossment'] = datav2[play_engrossment_cols].mean(axis=1)
datav2['Enjoyment'] = datav2[enjoyment_cols].mean(axis=1)
datav2['Personal Gratification'] = datav2[personal_gratification_cols].mean(axis=1)
datav2['Creative Freedom'] = datav2[creative_freedom_cols].mean(axis=1)
datav2['Social Connectivity'] = datav2[social_connectivity_cols].mean(axis=1)
datav2['Narrative'] = datav2[narrative_cols].mean(axis=1)
datav2['Usability/Playability'] = datav2[usability_cols].mean(axis=1)
datav2['Visual Aesthetics'] = datav2[visual_aesthetics_cols].mean(axis=1)


t_aest, p_aest = stats.ttest_rel(datav1['Aesthetics'], datav2['Aesthetics'])
t_playEngross, p_playEngross = stats.ttest_rel(datav1['Play Engrossment'], datav2['Play Engrossment'])
t_enjoy, p_enjoy = stats.ttest_rel(datav1['Enjoyment'], datav2['Enjoyment'])
t_personalGrat, p_personalGrat = stats.ttest_rel(datav1['Personal Gratification'], datav2['Personal Gratification'])
t_creativeFree, p_creativeFree = stats.ttest_rel(datav1['Creative Freedom'], datav2['Creative Freedom'])
t_socialConnect, p_socialConnect = stats.ttest_rel(datav1['Social Connectivity'], datav2['Social Connectivity'])
t_narrative, p_narrative = stats.ttest_rel(datav1['Narrative'], datav2['Narrative'])
t_usability, p_usability = stats.ttest_rel(datav1['Usability/Playability'], datav2['Usability/Playability'])
t_visualAest, p_visualAest = stats.ttest_rel(datav1['Visual Aesthetics'], datav2['Visual Aesthetics'])

final = pd.DataFrame({
    'Subescala': ['Aesthetics', 'Play Engrossment', 'Enjoyment',
                  'Personal Gratification', 'Creative Freedom',
                  'Social Connectivity', 'Narrative',
                  'Usability/Playability', 'Visual Aesthetics'],
    'p-valor': [p_aest, p_playEngross, p_enjoy,
                   p_personalGrat, p_creativeFree,
                   p_socialConnect, p_narrative,
                   p_usability, p_visualAest]
})
final
# Out:
#                 Subescala       p-valor
# 0              Aesthetics  3.613342e-15
# 1        Play Engrossment  1.227501e-21
# 2               Enjoyment  2.833366e-19
# 3  Personal Gratification  1.360935e-12
# 4        Creative Freedom  5.689545e-01
# 5     Social Connectivity  9.035560e-18
# 6               Narrative  3.855897e-16
# 7   Usability/Playability  4.430547e-18
# 8       Visual Aesthetics  5.529760e-17
